# %% [markdown]
# # Data Munging Basics
# ## Treating missing values

# %%
import pandas as pd
import numpy as np

from pandas import DataFrame, Series

# %% [markdown]
# ### Figuring out what data is missing

# %%
# np.nan can be used as a replacement for empty values
series_obj = Series(['row 1', 'row 2', 'row 3', np.nan, 'row 5', 'row 6', np.nan])
series_obj
# Out:
# 0    row 1
# 1    row 2
# 2    row 3
# 3      NaN
# 4    row 5
# 5    row 6
# 6      NaN
# dtype: object

# %%
# returns a series object stating in the values are null or not
series_obj.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool

# %% [markdown]
# ### Filling in for missing values

# %%
np.random.seed(25)
df_object = DataFrame(np.random.randn(36).reshape(6,6))
df_object
# Out:
#           0         1         2         3         4         5
# 0  0.228273  1.026890 -0.839585 -0.591182 -0.956888 -0.222326
# 1 -0.619915  1.837905 -2.053231  0.868583 -0.920734 -0.232312
# 2  2.152957 -1.334661  0.076380 -1.246089  1.202272 -1.049942
# 3  1.056610 -0.419678  2.294842 -2.594487  2.822756  0.680889
# 4 -1.577693 -1.976254  0.533340 -0.290870 -0.513520  1.982626
# 5  0.226001 -1.839905  1.607671  0.388292  0.399732  0.405477

# %%
# Set column 0 of rows 3-5 equal to NaN
df_object.loc[3:5, [0, 2]] = np.nan
df_object
# Out:
#           0         1         2         3         4         5
# 0  0.228273  1.026890 -0.839585 -0.591182 -0.956888 -0.222326
# 1 -0.619915  1.837905 -2.053231  0.868583 -0.920734 -0.232312
# 2  2.152957 -1.334661  0.076380 -1.246089  1.202272 -1.049942
# 3       NaN -0.419678       NaN -2.594487  2.822756  0.680889
# 4       NaN -1.976254       NaN -0.290870 -0.513520  1.982626
# 5       NaN -1.839905       NaN  0.388292  0.399732  0.405477

# %%
# Fill all NaN values with 0 - this diesn't change the original DF
df_object.fillna(0)
# Out:
#           0         1         2         3         4         5
# 0  0.228273  1.026890 -0.839585 -0.591182 -0.956888 -0.222326
# 1 -0.619915  1.837905 -2.053231  0.868583 -0.920734 -0.232312
# 2  2.152957 -1.334661  0.076380 -1.246089  1.202272 -1.049942
# 3  0.000000 -0.419678  0.000000 -2.594487  2.822756  0.680889
# 4  0.000000 -1.976254  0.000000 -0.290870 -0.513520  1.982626
# 5  0.000000 -1.839905  0.000000  0.388292  0.399732  0.405477

# %%
# A Dict can be passed to the fillna() method which is in the format of {column:value}
df_object.fillna({0:1, 2:45})
# Out:
#           0         1          2         3         4         5
# 0  0.228273  1.026890  -0.839585 -0.591182 -0.956888 -0.222326
# 1 -0.619915  1.837905  -2.053231  0.868583 -0.920734 -0.232312
# 2  2.152957 -1.334661   0.076380 -1.246089  1.202272 -1.049942
# 3  1.000000 -0.419678  45.000000 -2.594487  2.822756  0.680889
# 4  1.000000 -1.976254  45.000000 -0.290870 -0.513520  1.982626
# 5  1.000000 -1.839905  45.000000  0.388292  0.399732  0.405477

# %%
# Setting the key word 'method' argument to 'ffill' (stands for 'fill forward')
# will set all NaN values to the last non null value for that column
df_object.fillna(method='ffill')
# Out:
#           0         1         2         3         4         5
# 0  0.228273  1.026890 -0.839585 -0.591182 -0.956888 -0.222326
# 1 -0.619915  1.837905 -2.053231  0.868583 -0.920734 -0.232312
# 2  2.152957 -1.334661  0.076380 -1.246089  1.202272 -1.049942
# 3  2.152957 -0.419678  0.076380 -2.594487  2.822756  0.680889
# 4  2.152957 -1.976254  0.076380 -0.290870 -0.513520  1.982626
# 5  2.152957 -1.839905  0.076380  0.388292  0.399732  0.405477

# %% [markdown]
# ### Counting missing values

# %%
# Counts the number of null values in each column and returns a series object in the format of [column:count]
df_object.isnull().sum()
# Out:
# 0    3
# 1    0
# 2    3
# 3    0
# 4    0
# 5    0
# dtype: int64

# %% [markdown]
# ### Filtering out missing values

# %%
# Drop all rows that contain null values
df_object.dropna()
# Out:
#           0         1         2         3         4         5
# 0  0.228273  1.026890 -0.839585 -0.591182 -0.956888 -0.222326
# 1 -0.619915  1.837905 -2.053231  0.868583 -0.920734 -0.232312
# 2  2.152957 -1.334661  0.076380 -1.246089  1.202272 -1.049942

# %%
# Drop only the rows that contain all null values
df_object.dropna(how='all')
# Out:
#           0         1         2         3         4         5
# 0  0.228273  1.026890 -0.839585 -0.591182 -0.956888 -0.222326
# 1 -0.619915  1.837905 -2.053231  0.868583 -0.920734 -0.232312
# 2  2.152957 -1.334661  0.076380 -1.246089  1.202272 -1.049942
# 3       NaN -0.419678       NaN -2.594487  2.822756  0.680889
# 4       NaN -1.976254       NaN -0.290870 -0.513520  1.982626
# 5       NaN -1.839905       NaN  0.388292  0.399732  0.405477
