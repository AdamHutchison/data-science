# %% [markdown]
# # Data Visualization
# ## Segment 1 - Creating standard plots (line, bar, pie)

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
# Set data visualisation params
# Force matplotlib to show charts in notebook rather than external GUI
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sb.set_style('whitegrid')

# %% [markdown]
# ### Creating a line chart from a list object

# %% [markdown]
# #### Plotting a line chart in matplotlib

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]
plt.plot(x,y)

# %% [markdown]
# #### Plotting a line chart from a Pandas object

# %%
cars = pd.read_csv('./mtcars.csv')
cars.columns = ['car_names', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
cars.head()
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# You can directly plot a pandas series object using the plot() method
cars['mpg'].plot()

# %%
# You can also plot several columns on one graph
cars[['mpg', 'cyl', 'hp']].plot()

# %% [markdown]
# ### Creating bar charts
# #### Creating a bar chart from a list

# %%
# We can also easily plot a bar chart using pyplot's bar method
plt.bar(x, y)
# Out:
# <Container object of 9 artists>

# %% [markdown]
# #### Creating bar charts from Pandas objects

# %%
# We can also create a bar chart from a pandas object
cars['mpg'].plot(kind = 'bar')

# %%
# Set the plot methods 'kind' argument to 'barh' to get a horizontal bar chart
cars['mpg'].plot(kind = 'barh')

# %% [markdown]
# ### Creating a pie chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ### Saving a plot

# %%
# A graph can be saved as an image in the following way
plt.savefig('pie_chart.jpeg')
plt.show()
