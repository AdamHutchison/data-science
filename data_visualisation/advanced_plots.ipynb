# %% [markdown]
# # Data Visualization
# ## Segment 6 - Constructing histograms, box plots, and scatter plots

# %%
import pandas as pd
import seaborn as sb

from pandas.tools.plotting import scatter_matrix
from pylab import rcParams
from matplotlib import pyplot

# %%
# %matplotlib inline
rcParams['figure.figsize'] = [10, 8]
sb.set_style('whitegrid')

# %% [markdown]
# ### Eyeballing dataset distributions with histograms

# %%
cars = pd.read_csv('./mtcars.csv', index_col = 'car_names')
cars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# car_names
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# car_names
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
# A historgram can be created by calling the plt method off of a series
# edge color (ec) arg can be set to show dividers between columns
cars['mpg'].plot(kind='hist', ec='black')

# %%
# A historgram can also be created by calling the hist() method from pyplot
pyplot.hist(cars['mpg'], ec='black')
pyplot.plot()
# Out:
# []

# %%
# Seaborn can be used to produce a nice historgram with a distribution curve
sb.distplot(cars['mpg'])

# %% [markdown]
# ###  Seeing scatterplots in action

# %%
# x and y variables can be allocated using the x and y args
# c argument is for point colour
# s argument is for point size

cars.plot(kind='scatter', x='hp', y='mpg', c=['darkgrey'], s=150)

# %%
# We can also use seaborn to create a scatter graph
# set_title method can be used to set the title
sb.regplot(x='hp', y='mpg', data=cars, scatter=True).set_title('Graph')
# Out:
# Text(0.5,1,'Graph')

# %% [markdown]
# ### Generating a scatter plot matrix

# %%
sb.pairplot(cars)

# %% [markdown]
# ### Building boxplots

# %%
# Using pandas builtin functionallity
cars.boxplot(column='mpg', by='am')
cars.boxplot(column='wt', by='am')

# %%
# Seaborn can also be used to plot boxplots
sb.boxplot(x='am', y='mpg', data=cars, palette='hls')
